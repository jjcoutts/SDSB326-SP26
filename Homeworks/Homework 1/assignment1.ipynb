# %% [markdown]
# # Assignment 1: Working with Data
#
# This assignment covers **Chapters 1-4** from the [textbook](https://wesmckinney.com/book/) as well as lecture material from Weeks 1-3. Please complete this assignment by providing answers in cells after the question. Use **Code** cells to write and run any code you need to answer the question and **Markdown** cells to write out answers in words. After you are finished with the assignment, remember to download it as an **HTML file** and submit it in **ELMS**.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Question 1: Working with Sequences
#
# Answer the following questions by explaining the process, then show an example to show how it might be done. Create a list/array with a few numbers to demonstrate it.
#
# **a)** What would be a way to multiply each number in a **list** by 10 and get the output as a list?
#
# **b)** What would be a way to multiply each number in an **array** by 10 and get the output as a list?
#
# **c)** What would be a way to multiply each number in an **array** by 10 and get the output as an array?

# %% [markdown]
# ## Question 2: World Population
#
# **a)** You should have a CSV file called `world_population.csv` in the folder that this notebook is in. Create a list called `pop` that contains the values within `world_population.csv`. The values within `pop` should be integers.
#
# *Hint:* You can use the `int` function to convert individual strings into integers.

# %% [markdown]
# **b)** Using list comprehension, find the world population in billions of people. For example, the first value should be `2.557628654`. The output should be a list.

# %% [markdown]
# **c)** Find the world population in billions of people again, this time by first converting the list into an array. The output should also be an array.

# %% [markdown]
# ## Question 3: Functions
#
# Here are sample objects that we will use for testing:

# %%
li = [1,2,3,4,5]; print(li)
tu = (1,2,3,4,5); print(tu)
ar = np.array(tu); print(ar)

# %% [markdown]
# **a)** Write a function called **manual_mean** with one argument (DAT) that uses a LOOP to iterate across a seqeunce of numbers and outputs the mean. You should not use len(), np.mean(), or any other function (except when defining the loop, e.g., range(len(...))). **We are doing this by hand.**
#
# Hint: You should create objects outside of the loop to tally the length and sum of values.
#
# Use this function to find the mean of the sample objects above.

# %% [markdown]
# **b)** Write a function called **manual_VAR** with one argument (DAT) that uses a LOOP to iterate across a sequence of numbers and outputs the variance. You should not use len() or any other function (except when defining the loop). You CAN use the manual_mean function you created in **a)**. (You have the same hint as above.)
#
# The formula for variance is below:
#
# $$
# s^2 = \frac{\sum (x_i-\bar{x})^2} {n-1}
# $$
#
# Use this function (manual_VAR) to find the variances of the sample objects above.

# %% [markdown]
# **c)** Write a function called `mean_and_sd` that takes in a sequence of numbers and outputs two values: the mean and the standard deviation of that sequence of numbers. Make sure that it works with all of the following: lists, tuples, arrays, and Series. Have it generate an informative error message if the user did not input numbers (e.g., str or bool values). Tell the user what type of data they entered and what types of data they could enter. Finally, add an argument (decimals) that rounds the calculations to a specified value. Set the default to 3 decimal places.
#
# **For this question, you may use the functions you created or other functions that already exist. (Standard deviation is just the square root of variance.)**
#
# *Hint:* There are multiple ways to get the mean and the standard deviation. Some types of objects have methods that can do this!

# %% [markdown]
# # End of document
# Remember to run ALL cells before submitting to ELMS to receive full credit!
